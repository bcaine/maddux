# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from maddux.robots import Link, Arm
from maddux.environment import Environment
from maddux.robots import simple_human_arm
from maddux.robots import utils
import numpy as np

import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
# %matplotlib inline

# %%
q0 = np.array([1.5, 0.2, 0, 0.5, 1.5, 0.0, 0.0])
human_arm = simple_human_arm(2.0, 1.0, q0, np.array([5, 5, 10]))

# %%
env = Environment(robot=human_arm)

# %%
human_arm.update_link_velocity(1, 1.0, 2.0)
base = human_arm.end_effector_position()
pos = env.hypothetical_landing_position()

v = human_arm.end_effector_velocity()[0:3]


print "Base Position: {}".format(base)
print "Landing Position: {}".format(pos)

print "Velocity: {}".format(v)
# Out:
# Base Position: [ 5.06279507  5.89284616  8.48964229]
# Landing Position: [  5.3614415   10.09699335   1.02070564]
# Velocity: [ 0.21404065  3.01312284  1.79010299]

# %%
lamb = np.linspace(0, 1, 100)

x = base[0] + lamb * v[0]
y = base[1] + lamb * v[1]
z = base[2] + lamb * v[2] + -9.81 * lamb**2

# %%
fig = plt.figure(figsize=(8, 8))
ax = p3.Axes3D(fig)
ax.plot(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_ylim([0, 10])
# Out:
# (0, 10)

# %%
plt.plot(x)
plt.plot(y)
plt.plot(z)

# %%
# Out:
# array([ 8.48964229,  8.50672322,  8.52180232,  8.53487957,  8.54595499,
#         8.55502858,  8.56210032,  8.56717023,  8.57023831,  8.57130455,
#         8.57036895,  8.56743151,  8.56249224,  8.55555113,  8.54660819,
#         8.53566341,  8.52271679,  8.50776833,  8.49081804,  8.47186591,
#         8.45091195,  8.42795615,  8.40299851,  8.37603904,  8.34707773,
#         8.31611458,  8.2831496 ,  8.24818278,  8.21121412,  8.17224363,
#         8.1312713 ,  8.08829713,  8.04332113,  7.99634329,  7.94736361,
#         7.8963821 ,  7.84339875,  7.78841356,  7.73142654,  7.67243768,
#         7.61144699,  7.54845446,  7.48346009,  7.41646388,  7.34746584,
#         7.27646596,  7.20346425,  7.1284607 ,  7.05145531,  6.97244809,
#         6.89143902,  6.80842813,  6.72341539,  6.63640082,  6.54738442,
#         6.45636617,  6.36334609,  6.26832418,  6.17130042,  6.07227483,
#         5.97124741,  5.86821814,  5.76318705,  5.65615411,  5.54711934,
# ...
